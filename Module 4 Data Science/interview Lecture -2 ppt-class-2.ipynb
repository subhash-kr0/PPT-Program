# %%
  #my name is sunny

# %%
mystr="""shfhsd
sdghjsgsdfg
shglksdfg
shgklndfg
hsbkgndsfg
bdkgndf"""

# %%
len(mystr)
# Out:
# 57
# 57

# %%
from functools import reduce

# %%
class dun:
  def __init__(self,x,y):
    self.x = x
    self.y =y
  def __add__(self,other):
    return  (self.x +other.x,self.y + other.y)

  def __getitem__(self,index):
    if index==0:
      return self.x
    elif index ==1:
      return self.y
    else:
      return "out of range"

# %%
p = dun(2,3)
q = dun(4,3)
# p+q

# %%
q[1]
# Out:
# 3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mystr
# Out:
# 'shfhsd\nsdghjsgsdfg\nshglksdfg\nshgklndfg\nhsbkgndsfg\nbdkgndf'

# %%
id(mystr)
# Out:
# 140497869086304

# %%
import sys
sys.getsizeof(mystr)
# Out:
# 106

# %% [markdown]
# what is a difference between mutable and immutable

# %%
mylist=[1,2,3]

# %%
mytuple=(1,2,3)

# %%
mylist[1]=6

# %%
mylist
# Out:
# [1, 6, 3]

# %%
mytuple[1]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9564/1082423468.py in <module>
# ----> 1 mytuple[1]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
mylist=[1,2,3]

# %%
a,b,c=mylist

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
import copy
mylist=[[1,2],[3,4]]

# %%
mycopylist=copy.deepcopy(mylist)

# %%
id(mycopylist)
# Out:
# 1836011781696

# %%
mylist
# Out:
# [[1, 2], [3, 4]]

# %%
mycopylist
# Out:
# [[1, 2], [3, 4]]

# %%
mylist[0][0]=6

# %%
mylist
# Out:
# [[6, 2], [3, 4]]

# %%
mycopylist
# Out:
# [[1, 2], [3, 4]]

# %%
mycopylist[0][0]=7

# %%
mycopylist
# Out:
# [[7, 2], [3, 4]]

# %%
myshallowcopy=copy.copy(mylist)

# %%
mylist
# Out:
# [[6, 2], [3, 4]]

# %%
myshallowcopy
# Out:
# [[6, 2], [3, 4]]

# %%
mylist
# Out:
# [[1, 'sunny'], [3, 4]]

# %%
mylist[0][1]="rohit"

# %%
mylist[0][0]="data scientist"

# %%
mylist
# Out:
# [['data scientist', 'rohit'], [3, 4]]

# %%
myshallowcopy
# Out:
# [['data scientist', 'rohit'], [3, 4]]

# %%
#assigmenmt
print(id(mylist))
print(id(myshallowcopy))
# Out:
# 1836011635456
# 1836016641344

# %%
mylist=myshallowcopy

# %%
genrator
iteratoriterable
decorator
dundermethod
__name__=__main__
super()
class.__init__()
# Out:
#   File "<ipython-input-5-bdf02a8a7c06>", line 7
#     class.__init__()
#          ^
# SyntaxError: invalid syntax

# %%
mylist=[1,2,3,5,6]

# %%
mylist.append(100)

# %%
mylist
# Out:
# [1, 2, 3, 5, 6, 100]

# %%
mylist.append([100,200,300])

# %%
mylist
# Out:
# [1, 2, 3, 5, 6, 100, [100, 200, 300]]

# %%
mylist.extend([100,200,300])

# %%
mylist
# Out:
# [1, 2, 3, 5, 6, 100, [100, 200, 300], 100, 200, 300]

# %%
my_variable = 42
if isinstance(my_variable, int):
    print("Variable is an integer")
# Out:
# Variable is an integer

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = [x**2 for x in numbers]

# %%
squared_numbers
# Out:
# [1, 4, 9, 16, 25]

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list[-1:-4])
# Out:
# []

# %%
for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
def test(a,b):
    print(a,b)

# %%
#latest defination of the
def test(a,b,c):
    print(a,b,c)

# %%
test(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9564/3407544882.py in <module>
# ----> 1 test(1,2)
#
# TypeError: test() missing 1 required positional argument: 'c'

# %%
def my_function(*args):
    print(args)
    for arg in args:
        print(arg)

# %%
my_function(1, 2, 3)
# Out:
# (1, 2, 3)
# 1
# 2
# 3

# %%
my_function(1, 2)
# Out:
# (1, 2)
# 1
# 2

# %%
my_function(1, 2,23,54,5,6,56,346)
# Out:
# (1, 2, 23, 54, 5, 6, 56, 346)
# 1
# 2
# 23
# 54
# 5
# 6
# 56
# 346

# %%
def my_function(**kwargs):
    print(kwargs)
    for key, value in kwargs.items():
        print(key, value)

my_function(name="Alice", age=25)
# Out:
# {'name': 'Alice', 'age': 25}
# name Alice
# age 25

# %%
my_list = [1, 2, 3, 4, 5]
new_list = my_list.copy()

# %%
my_list[4]=100

# %%
my_list
# Out:
# [1, 2, 3, 4, 100]

# %%
id(my_list)
# Out:
# 1836016618560

# %%
new_list
# Out:
# [1, 2, 3, 4, 5]

# %%
id(new_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8635a558006c> in <cell line: 1>()
# ----> 1 id(new_list)
#
# NameError: name 'new_list' is not defined

# %%
my_list = ["Hello", "World"]
" ".join(my_list)
# Out:
# 'Hello World'

# %%
my_string = "Hello Hello World!"
my_string=my_string.split()

# %%
set(my_string)
# Out:
# {'Hello', 'World!'}

# %%
set(my_string)
# Out:
# {'Hello', 'Hello,', 'World!'}

# %%
my_string = "Hello Hello World!"
my_string=my_string.split()
" ".join(set(my_string))
# Out:
# 'Hello, Hello World!'

# %%
my_string = "Hello, hello World!"
unique_string = ''.join(set(my_string))

# %%
unique_string
# Out:
# ' HeWlo!dr,'

# %%
string_with_comma = "Hello, Hello World!"
string_without_comma = string_with_comma.replace(",", "")
print(string_without_comma)
# Out:
# Hello Hello World!

# %%
list1=[1,2,3]
list2=[1,2,3,4,5]
if list1 in list2:
    print("yes")

# %%
L1 = [1, 2, 3]
L2 = [1, 2, 3, 4, 5]

set1 = set(L1)
set2 = set(L2)

is_subset = set1.issubset(set2)

if is_subset:
    print("L1 is a subset of L2")
else:
    print("L1 is not a subset of L2")

# %%
l1 = [1,2,50]
l2 = [1,2,3,4,5]

for i in l1:
    if i not in l2:
        print("Not a subset")
        break

    else:
        print("It is a subset")
# Out:
# It is a subset
# It is a subset
# Not a subset

# %%
list1= [1,2,3,4,5]
list2= [1,2,3,5]
m=0
for i in range(len(list2)):
  if list2[i] in list1:
    m=1
  else:
    m=0
if m==1:
  print("subset")
else:
  print("not subset")
# Out:
# subset

# %%
range(len(list1))
# Out:
# range(0, 5)

# %%
arr=[2,1,8,9,12,15,11,19]
arr[4]
# Out:
# 12

# %%
arr.index(50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c005be1d168d> in <cell line: 1>()
# ----> 1 arr.index(50)
#
# ValueError: 50 is not in list

# %%
import time
def run_time(fun):
  def wrapper():
    start = time.time()
    fun()
    return f"program excution time is {time.time() -start} ms"
  return wrapper

# def num():
#   l = [i for i in range(100000)]
#   return l

# %%
@run_time
def nu():
  l = [i for i in range(100000)]
  return l


nu()
# Out:
# 'program excution time is 0.010219335556030273'

# %% [markdown]
# ##Trying myself

# %%
import copy

# %%
original_list = [1,2,[3,4]]

# %%
shallow_copy = copy.copy(original_list)

# %%
shallow_copy
# Out:
# [1, 2, [3, 4]]

# %%
original_list[0] = 5
original_list[2][0] = 6

# %%
original_list
# Out:
# [5, 2, [6, 4]]

# %%
shallow_copy
# Out:
# [1, 2, [6, 4]]

# %%
original_list[1] = 100

# %%
original_list
# Out:
# [5, 100, [6, 4]]

# %%
shallow_copy
# Out:
# [1, 2, [6, 4]]

# %%
prod = lambda a,b,c : a*b*c

# %%
prod(1,2,3)
# Out:
# 6

# %%
'''
sfssds
'''


"""
rjfgiorjfsdndlk
"""

# %%
# !pip install chatterbot
# Out:
# Collecting chatterbot
#   Using cached ChatterBot-1.0.5-py2.py3-none-any.whl (67 kB)
# Collecting mathparse<0.2,>=0.1 (from chatterbot)
#   Using cached mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: nltk<4.0,>=3.2 in /usr/local/lib/python3.10/dist-packages (from chatterbot) (3.8.1)
# Collecting pint>=0.8.1 (from chatterbot)
#   Using cached Pint-0.22-py3-none-any.whl (294 kB)
# Collecting pymongo<4.0,>=3.3 (from chatterbot)
#   Using cached pymongo-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (516 kB)
# Collecting python-dateutil<2.8,>=2.7 (from chatterbot)
#   Using cached python_dateutil-2.7.5-py2.py3-none-any.whl (225 kB)
# Collecting pyyaml<5.2,>=5.1 (from chatterbot)
#   Using cached PyYAML-5.1.2.tar.gz (265 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# Create a chatbot instance
chatbot = ChatBot('SimpleBot')

# Create a new trainer for the chatbot
trainer = ChatterBotCorpusTrainer(chatbot)

# Train the chatbot on the English language
trainer.train('chatterbot.corpus.english')

# Chat with the bot
while True:
    user_input = input('You: ')
    if user_input.lower() == 'exit':
        break
    response = chatbot.get_response(user_input)
    print('SimpleBot:', response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-35213b8ce5e5> in <cell line: 1>()
# ----> 1 from chatterbot import ChatBot
#       2 from chatterbot.trainers import ChatterBotCorpusTrainer
#       3
#       4 # Create a chatbot instance
#       5 chatbot = ChatBot('SimpleBot')
#
# ModuleNotFoundError: No module named 'chatterbot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install --ignore-installed PyYAML
# Out:
# Collecting PyYAML
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: PyYAML
# Successfully installed PyYAML-6.0.1

# %%
pip install chatterbot_corpus
# Out:
# Collecting chatterbot_corpus
#   Downloading chatterbot_corpus-1.2.0-py2.py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 3.7 MB/s eta 0:00:00
# Collecting PyYAML<4.0,>=3.12 (from chatterbot_corpus)
#   Downloading PyYAML-3.13.tar.gz (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 8.1 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import nltk
from nltk.chat.util import Chat, reflections

nltk.download('punkt')

# Define the chat pairs
pairs = [
    [
        r"hi|hello|hey",
        ["Hello!", "Hi there!", "How can I help you today?"]
    ],
    # You can add more conversation pairs here
]

# Create the chatbot
chatbot = Chat(pairs, reflections)

# Start the chat
print("Hello! I'm your chatbot. Type 'bye' to exit.")
chatbot.converse()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Hello! I'm your chatbot. Type 'bye' to exit.
# >hi i am vivek
# Hi there!
# >how are you
# None
# >do know me
# None
# >hi
# How can I help you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-bec93f14e2af> in <cell line: 20>()
#      18 # Start the chat
#      19 print("Hello! I'm your chatbot. Type 'bye' to exit.")
# ---> 20 chatbot.converse()
#
# /usr/local/lib/python3.10/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# !pip install rasa
# !pip install nest_asyncio
# Out:
# Collecting rasa
#   Downloading rasa-3.6.10-py3-none-any.whl (836 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.0/837.0 kB 8.9 MB/s eta 0:00:00
# Collecting CacheControl<0.13.0,>=0.12.9 (from rasa)
#   Downloading CacheControl-0.12.14-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: PyJWT[crypto]<3.0.0,>=2.0.0 in /usr/lib/python3/dist-packages (from rasa) (2.3.0)
# Collecting SQLAlchemy<1.5.0,>=1.4.0 (from rasa)
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py<1.5,>=0.9 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.4.0)
# Collecting aio-pika<8.2.4,>=6.7.1 (from rasa)
#   Downloading aio_pika-8.2.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.7 MB/s eta 0:00:00
# Collecting aiogram<2.26 (from rasa)
#   Downloading aiogram-2.25.1-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=3.7.4.post0,<3.9,>=3.6 in /usr/local/lib/python3.10/dist-packages (from rasa) (3.8.5)
# Collecting apscheduler<3.10,>=3.6 (from rasa)
#   Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.7 MB/s eta 0:00:00
# Collecting attrs<22.2,>=19.3 (from rasa)
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.4 MB/s eta 0:00:00
# Collecting boto3<2.0.0,>=1.26.136 (from rasa)
#   Downloading boto3-1.28.60-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from rasa) (2023.7.22)
# Requirement already satisfied: cloudpickle<2.3,>=1.2 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.2.1)
# Collecting colorclass<2.3,>=2.2 (from rasa)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Collecting coloredlogs<16,>=10 (from rasa)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Collecting colorhash<1.3.0,>=1.0.2 (from rasa)
#   Downloading colorhash-1.2.1-py3-none-any.whl (5.7 kB)
# Collecting confluent-kafka<3.0.0,>=1.9.2 (from rasa)
#   Downloading confluent_kafka-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=41.0.2 in /usr/local/lib/python3.10/dist-packages (from rasa) (41.0.4)
# Collecting dask==2022.10.2 (from rasa)
#   Downloading dask-2022.10.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.8 MB/s eta 0:00:00
# Collecting dnspython==2.3.0 (from rasa)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 33.0 MB/s eta 0:00:00
# Collecting fbmessenger<6.1.0,>=6.0.0 (from rasa)
#   Downloading fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: google-auth<3 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.17.3)
# Collecting joblib<1.3.0,>=0.15.1 (from rasa)
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: jsonpickle<3.1,>=1.3 in /usr/local/lib/python3.10/dist-packages (from rasa) (3.0.2)
# Collecting jsonschema<4.18,>=3.2 (from rasa)
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 13.0 MB/s eta 0:00:00
# Collecting matplotlib<3.6,>=3.1 (from rasa)
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 71.1 MB/s eta 0:00:00
# Collecting mattermostwrapper<2.3,>=2.2 (from rasa)
#   Downloading mattermostwrapper-2.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting networkx<2.7,>=2.4 (from rasa)
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.19.2 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.23.5)
# Collecting packaging<21.0,>=20.0 (from rasa)
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.3.0)
# Collecting portalocker<3.0.0,>=2.7.0 (from rasa)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa)
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 34.5 MB/s eta 0:00:00
# Collecting protobuf<4.23.4,>=4.23.3 (from rasa)
#   Downloading protobuf-4.23.3-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 34.9 MB/s eta 0:00:00
# Collecting psycopg2-binary<2.10.0,>=2.8.2 (from rasa)
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.8 MB/s eta 0:00:00
# Collecting pydantic<1.10.10 (from rasa)
#   Downloading pydantic-1.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: pydot<1.5,>=1.4 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.4.2)
# Collecting pykwalify<1.9,>=1.7 (from rasa)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Collecting pymongo[srv,tls]<4.4,>=3.8 (from rasa)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.8.2)
# Collecting python-engineio!=5.0.0,<6,>=4 (from rasa)
#   Downloading python_engineio-4.7.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 6.3 MB/s eta 0:00:00
# Collecting python-socketio<6,>=4.4 (from rasa)
#   Downloading python_socketio-5.9.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.5 MB/s eta 0:00:00
# Collecting pytz<2023.0,>=2019.1 (from rasa)
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (6.0.1)
# Collecting questionary<1.11.0,>=1.5.1 (from rasa)
#   Downloading questionary-1.10.0-py3-none-any.whl (31 kB)
# Collecting randomname<0.2.0,>=0.1.5 (from rasa)
#   Downloading randomname-0.1.5.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rasa-sdk<3.7.0,>=3.6.2 (from rasa)
#   Downloading rasa_sdk-3.6.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 4.9 MB/s eta 0:00:00
# Collecting redis<5.0,>=4.5.3 (from rasa)
#   Downloading redis-4.6.0-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.1/241.1 kB 25.9 MB/s eta 0:00:00
# Collecting regex<2022.11,>=2020.6 (from rasa)
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.10/dist-packages (from rasa) (2.31.0)
# Collecting rocketchat_API<1.31.0,>=0.6.31 (from rasa)
#   Downloading rocketchat_API-1.30.0-py3-none-any.whl (21 kB)
# Collecting ruamel.yaml<0.17.22,>=0.16.5 (from rasa)
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 12.2 MB/s eta 0:00:00
# Collecting sanic<21.13,>=21.12 (from rasa)
#   Downloading sanic-21.12.2-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 17.8 MB/s eta 0:00:00
# Collecting sanic-cors<2.1.0,>=2.0.0 (from rasa)
#   Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# Collecting sanic-jwt<2.0.0,>=1.6.0 (from rasa)
#   Downloading sanic_jwt-1.8.0-py3-none-any.whl (23 kB)
# Collecting sanic-routing<0.8.0,>=0.7.2 (from rasa)
#   Downloading sanic_routing-0.7.2-py3-none-any.whl (23 kB)
# Collecting scikit-learn<1.2,>=0.22 (from rasa)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from rasa) (1.11.3)
# Collecting sentry-sdk<1.15.0,>=0.17.0 (from rasa)
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from rasa) (67.7.2)
# Collecting sklearn-crfsuite<0.4,>=0.3 (from rasa)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting slack-sdk<4.0.0,>=3.19.2 (from rasa)
#   Downloading slack_sdk-3.23.0-py2.py3-none-any.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.0/281.0 kB 30.3 MB/s eta 0:00:00
# Collecting structlog<24.0.0,>=23.1.0 (from rasa)
#   Downloading structlog-23.1.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.5 MB/s eta 0:00:00
# Collecting structlog-sentry<3.0.0,>=2.0.2 (from rasa)
#   Downloading structlog_sentry-2.0.3-py3-none-any.whl (10 kB)
# Collecting tarsafe<0.0.5,>=0.0.3 (from rasa)
#   Downloading tarsafe-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting tensorflow==2.12.0 (from rasa)
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.7 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem==0.32 (from rasa)
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 103.4 MB/s eta 0:00:00
# Collecting tensorflow-text==2.12.0 (from rasa)
#   Downloading tensorflow_text-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 110.2 MB/s eta 0:00:00
# Collecting tensorflow_hub<0.14.0,>=0.13.0 (from rasa)
#   Downloading tensorflow_hub-0.13.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 12.0 MB/s eta 0:00:00
# Collecting terminaltables<3.2.0,>=3.1.0 (from rasa)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm<5.0,>=4.31 in /usr/local/lib/python3.10/dist-packages (from rasa) (4.66.1)
# Collecting twilio<8.3,>=6.26 (from rasa)
#   Downloading twilio-8.2.2-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from rasa) (4.5.0)
# Collecting typing-utils<0.2.0,>=0.1.0 (from rasa)
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting ujson<6.0,>=1.35 (from rasa)
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 5.0 MB/s eta 0:00:00
# Collecting webexteamssdk<1.7.0,>=1.1.1 (from rasa)
#   Downloading webexteamssdk-1.6.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 14.2 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from rasa)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.38.1 in /usr/local/lib/python3.10/dist-packages (from rasa) (0.41.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (8.1.7)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (2023.6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (1.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa) (0.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.58.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (0.4.14)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0->rasa)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.7 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow==2.12.0->rasa)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 40.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow==2.12.0->rasa)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0->rasa) (2.3.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.12.0->rasa)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
# Collecting aiormq~=6.4.0 (from aio-pika<8.2.4,>=6.7.1->rasa)
#   Downloading aiormq-6.4.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: yarl in /usr/local/lib/python3.10/dist-packages (from aio-pika<8.2.4,>=6.7.1->rasa) (1.9.2)
# Collecting Babel<2.10.0,>=2.9.1 (from aiogram<2.26->rasa)
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 48.3 MB/s eta 0:00:00
# Collecting magic-filter>=1.0.9 (from aiogram<2.26->rasa)
#   Downloading magic_filter-1.0.12-py3-none-any.whl (11 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.3.1)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa) (5.0.1)
# Collecting botocore<1.32.0,>=1.31.60 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading botocore-1.31.60-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 17.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3<2.0.0,>=1.26.136->rasa)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from CacheControl<0.13.0,>=0.12.9->rasa) (1.0.7)
# Collecting humanfriendly>=9.1 (from coloredlogs<16,>=10->rasa)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=41.0.2->rasa) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa) (4.9)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.18,>=3.2->rasa)
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa) (3.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa) (0.2.7)
# Collecting docopt>=0.6.2 (from pykwalify<1.9,>=1.7->rasa)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting simple-websocket>=0.10.0 (from python-engineio!=5.0.0,<6,>=4->rasa)
#   Downloading simple_websocket-0.10.1-py3-none-any.whl (7.5 kB)
# Collecting bidict>=0.21.0 (from python-socketio<6,>=4.4->rasa)
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting fire (from randomname<0.2.0,>=0.1.5->rasa)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa) (2.0.5)
# Collecting ruamel.yaml.clib>=0.2.6 (from ruamel.yaml<0.17.22,>=0.16.5->rasa)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 28.7 MB/s eta 0:00:00
# Collecting httptools>=0.0.10 (from sanic<21.13,>=21.12->rasa)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 36.9 MB/s eta 0:00:00
# Collecting aiofiles>=0.6.0 (from sanic<21.13,>=21.12->rasa)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 17.1 MB/s eta 0:00:00
# Collecting uvloop>=0.5.3 (from sanic<21.13,>=21.12->rasa)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 59.0 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2,>=0.22->rasa) (3.2.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite<0.4,>=0.3->rasa)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 60.8 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa) (2.0.2)
# Collecting aiohttp-retry>=2.8.3 (from twilio<8.3,>=6.26->rasa)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.18.3)
# Collecting requests-toolbelt (from webexteamssdk<1.7.0,>=1.1.1->rasa)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.3 MB/s eta 0:00:00
# Collecting pamqp==3.2.1 (from aiormq~=6.4.0->aio-pika<8.2.4,>=6.7.1->rasa)
#   Downloading pamqp-3.2.1-py2.py3-none-any.whl (33 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.23->rasa)
#   Downloading urllib3-1.26.17-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=41.0.2->rasa) (2.21)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0->rasa) (0.3.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa) (0.5.0)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (2.3.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (2.1.3)
# Collecting h11<1,>=0.9.0 (from wsproto->simple-websocket>=0.10.0->python-engineio!=5.0.0,<6,>=4->rasa)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->rasa) (3.2.2)
# Building wheels for collected packages: mattermostwrapper, randomname, docopt, fire
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-py3-none-any.whl size=2446 sha256=9de59c807628c4332c36511d834e4c11417d673ca4ab06071a50306cb4d84063
#   Stored in directory: /root/.cache/pip/wheels/b2/dc/02/e3239f0ea0a676085826846d32ef09b10915c0a33c817d2dbb
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.1.5-py3-none-any.whl size=58807 sha256=78319e4c7d6b289776f653b518b2c785c689bb23040506790e7aec3fc28deeb7
#   Stored in directory: /root/.cache/pip/wheels/ee/df/c1/0bdf17c694217f49657ca36fd0239b9a243c34c27a70ff56ef
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=18be8411946f8fb14ac722d73fdacfba3af5e68365173505499d28baca9b5949
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=d86d121d7b16dae2386166596cbce246088a7ac4082108a22fe1db9c696bd0b1
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built mattermostwrapper randomname docopt fire
# Installing collected packages: sanic-routing, pytz, python-crfsuite, docopt, confluent-kafka, wrapt, websockets, uvloop, urllib3, ujson, typing-utils, terminaltables, tensorflow-io-gcs-filesystem, tensorflow-estimator, tarsafe, structlog, SQLAlchemy, slack-sdk, sklearn-crfsuite, sanic-jwt, ruamel.yaml.clib, regex, redis, pyrsistent, pydantic, psycopg2-binary, protobuf, prompt-toolkit, portalocker, pamqp, packaging, networkx, multidict, magic-filter, keras, joblib, jmespath, humanfriendly, httptools, h11, fire, dnspython, colorhash, colorclass, bidict, Babel, attrs, apscheduler, aiofiles, wsproto, tensorflow_hub, sentry-sdk, scikit-learn, sanic, ruamel.yaml, randomname, questionary, pymongo, matplotlib, jsonschema, dask, coloredlogs, botocore, structlog-sentry, simple-websocket, sanic-cors, s3transfer, rocketchat_API, requests-toolbelt, pykwalify, mattermostwrapper, fbmessenger, CacheControl, aiormq, webexteamssdk, rasa-sdk, python-engineio, boto3, aiohttp-retry, aiogram, aio-pika, twilio, tensorboard, python-socketio, tensorflow, tensorflow-text, rasa
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3.post1
#     Uninstalling pytz-2023.3.post1:
#       Successfully uninstalled pytz-2023.3.post1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.5
#     Uninstalling urllib3-2.0.5:
#       Successfully uninstalled urllib3-2.0.5
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.34.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.34.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.34.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.21
#     Uninstalling SQLAlchemy-2.0.21:
#       Successfully uninstalled SQLAlchemy-2.0.21
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.6.3
#     Uninstalling regex-2023.6.3:
#       Successfully uninstalled regex-2023.6.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:

# %%
my_list = [1, 2, 3, 4, 5]

print(my_list[1:4])
# Out:
# [2, 3, 4]

# %%
my_dict = {"name": "John", "age": 25}

print(len(my_dict))
# Out:
# 2

# %%
print(3 > 2 > 1)
# Out:
# True
